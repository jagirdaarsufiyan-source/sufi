# %%
import requests

# Enter your city
city = "Bangalore"

# API URL (Sign up and get a free key from: https://openweathermap.org/api)
api_key = "YOUR_API_KEY"
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

response = requests.get(url)
data = response.json()

if data.get("cod") != 200:
    print("City not found or invalid API key")
else:
    # Extract key values
    temperature = data["main"]["temp"]
    feels_like = data["main"]["feels_like"]
    humidity = data["main"]["humidity"]
    weather = data["weather"][0]["description"]

    print(f"Weather in {city}:")
    print(f"Temperature: {temperature}°C")
    print(f"Feels Like: {feels_like}°C")
    print(f"Humidity: {humidity}%")
    print(f"Description: {weather}")

    # Simple analysis
    if temperature > 35:
        print("It's quite hot today. Stay hydrated.")
    elif 20 <= temperature <= 30:
        print("The weather is comfortable.")
    else:
        print("It's a bit cool. You may need a light jacket.")
# Out:
# City not found or invalid API key

# %%
print("It's a bit cool. You may need a light jacket.")
# Out:
# It's a bit cool. You may need a light jacket.
